# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !rm -rf /content/accent_detector
# !git clone https://github.com/JB-uses-git/accent_detector.git
# %cd /content/accent_detector
# !pip install -q -r requirements.txt
# !cp -r /content/drive/MyDrive/accent_detector_model /content/accent_detector/accent-classifier-final
# !cp -r /content/drive/MyDrive/indian_subaccent_model /content/accent_detector/indian-subaccent-classifier

# %%
# !python app.py --share
